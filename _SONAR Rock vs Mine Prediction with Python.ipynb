# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# data collection and data processing

# %%
df=pd.read_csv(r"C:\Users\Prithweeraz\Desktop\dataset\Copy of sonar data.csv",header=None)

# %%
df.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  60
# 0  0.0090  0.0032   R
# 1  0.0052  0.0044   R
# 2  0.0095  0.0078   R
# ...

# %%
df.shape
# Out:
# (207, 61)

# %%
df.describe()
# Out:
#                0           1           2           3           4           5   \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892    0.075202    0.104570
# std      0.022991    0.032960    0.038428    0.046528    0.055552    0.059105
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013350    0.016450    0.018950    0.024375    0.038050    0.067025
# 50%      0.022800    0.030800    0.034300    0.044050    0.062500    0.092150
# 75%      0.035550    0.047950    0.057950    0.064500    0.100275    0.134125
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#                6           7           8           9   ...          50  \
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000
# mean     0.121747    0.134799    0.178003    0.208259  ...    0.016069
# ...

# %%
df.groupby(60).mean()
# Out:
#           0         1         2         3         4         5         6   \
# 60
# M   0.034989  0.045544  0.050720  0.064768  0.086715  0.111864  0.128359
# R   0.022498  0.030303  0.035951  0.041447  0.062028  0.096224  0.114180
#
#           7         8         9   ...        50        51        52        53  \
# 60                                ...
# M   0.149832  0.213492  0.251022  ...  0.019352  0.016014  0.011643  0.012185
# R   0.117596  0.137392  0.159325  ...  0.012311  0.010453  0.009640  0.009518
#
#           54        55        56        57        58        59
# 60
# M   0.009923  0.008914  0.007825  0.009060  0.008695  0.006930
# R   0.008567  0.007430  0.007814  0.006677  0.007078  0.006024
#
# [2 rows x 60 columns]

# %%
df[60].value_counts()
# Out:
# 60
# M    111
# R     97
# Name: count, dtype: int64

# %%
x=df.drop(columns=60,axis=1)
y=df[60]

# %%
#feature importance:
from sklearn.ensemble import ExtraTreesClassifier

# %%
model= ExtraTreesClassifier()

# %%
model.fit(x,y)
# Out:
# ExtraTreesClassifier()

# %%
model.feature_importances_
# Out:
# array([0.01416718, 0.01248751, 0.00987142, 0.01551024, 0.01330847,
#        0.0144796 , 0.01131454, 0.01376885, 0.02785383, 0.02299374,
#        0.04619311, 0.04775138, 0.02250283, 0.01094758, 0.01230237,
#        0.0144856 , 0.01780405, 0.01683504, 0.01366235, 0.01757251,
#        0.02131127, 0.01741363, 0.01653875, 0.01409101, 0.01121501,
#        0.01244735, 0.01818548, 0.02104973, 0.01217817, 0.01260899,
#        0.01694093, 0.01129768, 0.01102939, 0.01210685, 0.01629692,
#        0.02890569, 0.02238296, 0.0107287 , 0.01224299, 0.01016851,
#        0.01157111, 0.01375674, 0.0161635 , 0.01938478, 0.02579368,
#        0.01867057, 0.02073007, 0.02933194, 0.02878101, 0.00863514,
#        0.01667973, 0.02126716, 0.01028306, 0.01190893, 0.01197368,
#        0.00814983, 0.01013552, 0.010988  , 0.01108458, 0.00975875])

# %%
top
# Out:
# 0     0.014167
# 1     0.012488
# 2     0.009871
# 3     0.015510
# 4     0.013308
# 5     0.014480
# 6     0.011315
# 7     0.013769
# 8     0.027854
# 9     0.022994
# 10    0.046193
# 11    0.047751
# 12    0.022503
# 13    0.010948
# 14    0.012302
# 15    0.014486
# 16    0.017804
# 17    0.016835
# 18    0.013662
# 19    0.017573
# 20    0.021311
# 21    0.017414
# 22    0.016539
# 23    0.014091
# 24    0.011215
# 25    0.012447
# 26    0.018185
# 27    0.021050
# 28    0.012178
# 29    0.012609
# 30    0.016941
# 31    0.011298
# 32    0.011029
# 33    0.012107
# 34    0.016297
# 35    0.028906
# 36    0.022383
# 37    0.010729
# 38    0.012243
# 39    0.010169
# 40    0.011571
# 41    0.013757
# 42    0.016164
# 43    0.019385
# 44    0.025794
# 45    0.018671
# 46    0.020730
# 47    0.029332
# 48    0.028781
# 49    0.008635
# 50    0.016680
# 51    0.021267
# 52    0.010283
# 53    0.011909
# 54    0.011974
# 55    0.008150
# 56    0.010136
# 57    0.010988
# ...

# %%
top.nlargest(59).plot(kind='bar')  #ancending order of
# Out:
# <Axes: >

# %%
top=pd.Series(model.feature_importances_, index=x.columns)

# %%
print(x.shape,xtrain.shape,x)
# Out:
# (208, 60) (166, 60) (42, 60)

# %%
print(y.shape,ytrain.shape,ytest.shape)
# Out:
# (208,) (166,) (42,)

# %%
model= LogisticRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
accuracy=accuracy_score(xtrain_pred,ytrain)

# %%
 accuracy
# Out:
# 0.8433734939759037

# %%
xtsest_pred=model.predict(xtest)

# %%
acccuray_test_data= accuracy_score(xtsest_pred,ytest)

# %%
acccuray_test_data
# Out:
# 0.6904761904761905

# %%
#model prediction
input_data = (0.0307,0.0523,0.0653,0.0521,0.0611,0.0577,0.0665,0.0664,0.1460,0.2792,0.3877,0.4992,0.4981,0.4972,0.5607,0.7339,0.8230,0.9173,0.9975,0.9911,0.8240,0.6498,0.5980,0.4862,0.3150,0.1543,0.0989,0.0284,0.1008,0.2636,0.2694,0.8941,0.2925,0.3998,0.3660,0.3172,0.4609,0.4374,0.1820,0.3376,0.6202,0.4448,0.1863,0.1420,0.0589,0.0576,0.0672,0.0269,0.0245,0.0190,0.0063,0.0321,0.0189,0.0137,0.0277,0.0152,0.0052,0.0121,0.0124,0.0055)

# %%
input_dataas_numpy_array=np.asarray(input_data)

# %%
input_dataas_numpy_array
# Out:
# array([0.0307, 0.0523, 0.0653, 0.0521, 0.0611, 0.0577, 0.0665, 0.0664,
#        0.146 , 0.2792, 0.3877, 0.4992, 0.4981, 0.4972, 0.5607, 0.7339,
#        0.823 , 0.9173, 0.9975, 0.9911, 0.824 , 0.6498, 0.598 , 0.4862,
#        0.315 , 0.1543, 0.0989, 0.0284, 0.1008, 0.2636, 0.2694, 0.8941,
#        0.2925, 0.3998, 0.366 , 0.3172, 0.4609, 0.4374, 0.182 , 0.3376,
#        0.6202, 0.4448, 0.1863, 0.142 , 0.0589, 0.0576, 0.0672, 0.0269,
#        0.0245, 0.019 , 0.0063, 0.0321, 0.0189, 0.0137, 0.0277, 0.0152,
#        0.0052, 0.0121, 0.0124, 0.0055])

# %%
input_data_resaped=input_dataas_numpy_array.reshape(1,-1)

# %%
input_data_resaped
# Out:
# array([[0.0307, 0.0523, 0.0653, 0.0521, 0.0611, 0.0577, 0.0665, 0.0664,
#         0.146 , 0.2792, 0.3877, 0.4992, 0.4981, 0.4972, 0.5607, 0.7339,
#         0.823 , 0.9173, 0.9975, 0.9911, 0.824 , 0.6498, 0.598 , 0.4862,
#         0.315 , 0.1543, 0.0989, 0.0284, 0.1008, 0.2636, 0.2694, 0.293 ,
#         0.2925, 0.3998, 0.366 , 0.3172, 0.4609, 0.4374, 0.182 , 0.3376,
#         0.6202, 0.4448, 0.1863, 0.142 , 0.0589, 0.0576, 0.0672, 0.0269,
#         0.0245, 0.019 , 0.0063, 0.0321, 0.0189, 0.0137, 0.0277, 0.0152,
#         0.0052, 0.0121, 0.0124, 0.0055]])

# %%
prediction=model.predict(input_data_resaped)
print(prediction)
if(prediction[0]=='R'):
 print("The object is a rock")
else:
 print("the object is a mine")
# Out:
# ['M']
# the object is a mine
